# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sales_data_1 (4).csv")

# %%
df
# Out:
#         Date Firm bought from  Buying price   Customer  Selling price  \
# 0   21/08/23          Vendor6         72.11  Customer7          91.58
# 1   21/08/23          Vendor4         75.08  Customer7          83.71
# 2   21/08/23          Vendor7         83.93  Customer2         103.76
# 3   21/08/23          Vendor7         52.01  Customer3          64.53
# 4   21/08/23          Vendor2         98.91  Customer5         140.92
# ..       ...              ...           ...        ...            ...
# 65  27/08/23          Vendor4         64.82  Customer6          87.45
# 66  27/08/23          Vendor8         88.79  Customer3         105.59
# 67  27/08/23          Vendor5         63.30  Customer5          92.92
# 68  27/08/23          Vendor5         94.06  Customer5         125.67
# 69  27/08/23          Vendor5         56.28  Customer6          82.16
#
#     Quantity sold
# 0              44
# 1              17
# 2              15
# 3               7
# 4               1
# ...

# %%
df['Profit'] = (df['Selling price']- df['Buying price'])*df['Quantity sold']

# %%
df
# Out:
#         Date Firm bought from  Buying price   Customer  Selling price  \
# 0   21/08/23          Vendor6         72.11  Customer7          91.58
# 1   21/08/23          Vendor4         75.08  Customer7          83.71
# 2   21/08/23          Vendor7         83.93  Customer2         103.76
# 3   21/08/23          Vendor7         52.01  Customer3          64.53
# 4   21/08/23          Vendor2         98.91  Customer5         140.92
# ..       ...              ...           ...        ...            ...
# 65  27/08/23          Vendor4         64.82  Customer6          87.45
# 66  27/08/23          Vendor8         88.79  Customer3         105.59
# 67  27/08/23          Vendor5         63.30  Customer5          92.92
# 68  27/08/23          Vendor5         94.06  Customer5         125.67
# 69  27/08/23          Vendor5         56.28  Customer6          82.16
#
#     Quantity sold  Profit
# 0              44  856.68
# 1              17  146.71
# 2              15  297.45
# ...

# %%
df['Gross margin'] = df['Profit']/(df['Selling price']*df['Quantity sold'])*100

# %%
df
# Out:
#         Date Firm bought from  Buying price   Customer  Selling price  \
# 0   21/08/23          Vendor6         72.11  Customer7          91.58
# 1   21/08/23          Vendor4         75.08  Customer7          83.71
# 2   21/08/23          Vendor7         83.93  Customer2         103.76
# 3   21/08/23          Vendor7         52.01  Customer3          64.53
# 4   21/08/23          Vendor2         98.91  Customer5         140.92
# ..       ...              ...           ...        ...            ...
# 65  27/08/23          Vendor4         64.82  Customer6          87.45
# 66  27/08/23          Vendor8         88.79  Customer3         105.59
# 67  27/08/23          Vendor5         63.30  Customer5          92.92
# 68  27/08/23          Vendor5         94.06  Customer5         125.67
# 69  27/08/23          Vendor5         56.28  Customer6          82.16
#
#     Quantity sold  Profit  Gross margin
# 0              44  856.68     21.260100
# 1              17  146.71     10.309402
# ...

# %%
df['Gross margin'].sum()  #total gross margin
# Out:
# 1518.9048276740848

# %%
df['Gross margin'].sum()/70 #average GM
# Out:
# 21.698640395344068

# %%
df.groupby('Firm bought from')['Profit'].sum()
# Out:
# Firm bought from
# Vendor1     1555.59
# Vendor10    3040.62
# Vendor2     1296.98
# Vendor3     6370.67
# Vendor4     6903.31
# Vendor5     1616.14
# Vendor6     1217.95
# Vendor7     4961.05
# Vendor8      253.74
# Vendor9     4266.70
# Name: Profit, dtype: float64

# %%
df.groupby('Firm bought from')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Firm bought from
# Vendor4    6903.31
# Name: Profit, dtype: float64

# %%
df.groupby('Firm bought from')['Profit'].sum().sort_values(ascending=False).tail(1)
# Out:
# Firm bought from
# Vendor8    253.74
# Name: Profit, dtype: float64

# %%
df.groupby('Customer')['Profit'].sum()
# Out:
# Customer
# Customer1     5310.57
# Customer10    3692.44
# Customer2     4215.67
# Customer3     1055.05
# Customer4     3337.37
# Customer5     1315.28
# Customer6     1930.76
# Customer7     2197.62
# Customer8     6498.91
# Customer9     1929.08
# Name: Profit, dtype: float64

# %%
df.groupby('Customer')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Customer
# Customer8    6498.91
# Name: Profit, dtype: float64

# %%
df.groupby('Customer')['Profit'].sum().sort_values(ascending=False).tail(1)
# Out:
# Customer
# Customer3    1055.05
# Name: Profit, dtype: float64

# %%
df.groupby('Date')['Profit'].sum()
# Out:
# Date
# 21/08/23    6847.34
# 22/08/23    3305.35
# 23/08/23    4392.47
# 24/08/23    4866.03
# 25/08/23    3761.94
# 26/08/23    5223.16
# 27/08/23    3086.46
# Name: Profit, dtype: float64

# %%
df.groupby('Date')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Date
# 21/08/23    6847.34
# Name: Profit, dtype: float64

# %%
df.groupby('Date')['Profit'].sum().sort_values(ascending=False).tail(1)
# Out:
# Date
# 27/08/23    3086.46
# Name: Profit, dtype: float64

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sales_data_2.csv")

# %%
df
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 0   2023-08-21          Vendor6         72.11               60  Customer7
# 1   2023-08-21          Vendor4         75.08               92  Customer7
# 2   2023-08-21          Vendor7         83.93               16  Customer2
# 3   2023-08-21          Vendor7         52.01               62  Customer3
# 4   2023-08-21          Vendor2         98.91                1  Customer5
# ..         ...              ...           ...              ...        ...
# 65  2023-08-27          Vendor4         64.82               28  Customer6
# 66  2023-08-27          Vendor8         88.79               14  Customer3
# 67  2023-08-27          Vendor5         63.30               81  Customer5
# 68  2023-08-27          Vendor5         94.06               18  Customer5
# 69  2023-08-27          Vendor5         56.28               25  Customer6
#
#     Selling price  Quantity sold
# 0           91.58             44
# ...

# %%
df['Profit'] = (df['Selling price']- df['Buying price'])*df['Quantity sold']

# %%
df
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 0   2023-08-21          Vendor6         72.11               60  Customer7
# 1   2023-08-21          Vendor4         75.08               92  Customer7
# 2   2023-08-21          Vendor7         83.93               16  Customer2
# 3   2023-08-21          Vendor7         52.01               62  Customer3
# 4   2023-08-21          Vendor2         98.91                1  Customer5
# ..         ...              ...           ...              ...        ...
# 65  2023-08-27          Vendor4         64.82               28  Customer6
# 66  2023-08-27          Vendor8         88.79               14  Customer3
# 67  2023-08-27          Vendor5         63.30               81  Customer5
# 68  2023-08-27          Vendor5         94.06               18  Customer5
# 69  2023-08-27          Vendor5         56.28               25  Customer6
#
#     Selling price  Quantity sold  Profit
# ...

# %%
df['Profit %']= (df['Profit']/(df['Buying price']*df['Quantity sold']))*100

# %%
df
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 0   2023-08-21          Vendor6         72.11               60  Customer7
# 1   2023-08-21          Vendor4         75.08               92  Customer7
# 2   2023-08-21          Vendor7         83.93               16  Customer2
# 3   2023-08-21          Vendor7         52.01               62  Customer3
# 4   2023-08-21          Vendor2         98.91                1  Customer5
# ..         ...              ...           ...              ...        ...
# 65  2023-08-27          Vendor4         64.82               28  Customer6
# 66  2023-08-27          Vendor8         88.79               14  Customer3
# 67  2023-08-27          Vendor5         63.30               81  Customer5
# 68  2023-08-27          Vendor5         94.06               18  Customer5
# 69  2023-08-27          Vendor5         56.28               25  Customer6
#
#     Selling price  Quantity sold  Profit   Profit %
# ...

# %%
df['sold %'] = (df['Quantity sold']/df['Quantity bought'])*100

# %%
df
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 0   2023-08-21          Vendor6         72.11               60  Customer7
# 1   2023-08-21          Vendor4         75.08               92  Customer7
# 2   2023-08-21          Vendor7         83.93               16  Customer2
# 3   2023-08-21          Vendor7         52.01               62  Customer3
# 4   2023-08-21          Vendor2         98.91                1  Customer5
# ..         ...              ...           ...              ...        ...
# 65  2023-08-27          Vendor4         64.82               28  Customer6
# 66  2023-08-27          Vendor8         88.79               14  Customer3
# 67  2023-08-27          Vendor5         63.30               81  Customer5
# 68  2023-08-27          Vendor5         94.06               18  Customer5
# 69  2023-08-27          Vendor5         56.28               25  Customer6
#
#     Selling price  Quantity sold  Profit   Profit %      sold %
# ...

# %%
df.sort_values(by='sold %',ascending=False).head(1)
# Out:
#          Date Firm bought from  Buying price  Quantity bought   Customer  \
# 7  2023-08-21          Vendor3         98.11               62  Customer2
#
#    Selling price  Quantity sold  Profit   Profit %  sold %
# 7         146.76             62  3016.3  49.587198   100.0

# %%
df.sort_values(by='Profit %',ascending=False).head(1)
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 58  2023-08-26          Vendor9         64.69               22  Customer1
#
#     Selling price  Quantity sold  Profit   Profit %     sold %
# 58          97.02              7  226.31  49.976812  31.818182

# %%
ds=pd.DataFrame()

# %%
pavis = df.groupby(['Firm bought from','Customer']).agg({'Buying price':'sum','Quantity bought':'sum','Quantity sold':'sum','Selling price':'sum'})
pavis
# Out:
#                              Buying price  Quantity bought  Quantity sold  \
# Firm bought from Customer
# Vendor1          Customer10         52.63               96             54
#                  Customer2          40.63               49              1
#                  Customer3          20.95               95             22
#                  Customer6          64.52               76             11
#                  Customer8          17.62               81             74
# Vendor10         Customer1          38.79               94             47
#                  Customer3          46.33               86             42
#                  Customer6          59.01               61             34
#                  Customer8         103.48              110             66
# Vendor2          Customer10         78.70                2              1
#                  Customer2          42.84               99              9
# ...

# %%
ds['selling price'] = df.groupby('Firm bought from')['Selling price'].sum()

# %%
ds['buying price'] = df.groupby('Firm bought from')['Buying price'].sum()

# %%
ds['quantity bought'] = df.groupby('Firm bought from')['Quantity bought'].sum()

# %%
ds['quantity sold'] = df.groupby('Firm bought from')['Quantity sold'].sum()

# %%
ds
# Out:
#                   selling price  buying price  quantity bought  quantity sold
# Firm bought from
# Vendor1                  249.58        196.35              397            162
# Vendor10                 330.19        247.61              351            189
# Vendor2                  700.10        538.99              424            207
# Vendor3                  616.61        451.43              351            229
# Vendor4                  741.28        571.17              548            272
# Vendor5                  527.66        410.68              323             96
# Vendor6                  151.88        119.77              126             79
# Vendor7                 1054.14        829.16              629            270
# Vendor8                  201.80        166.14              133             23
# Vendor9                  600.69        435.43              279            170

# %%
df.groupby('Customer')['Profit'].sum()
# Out:
# Customer
# Customer1     5310.57
# Customer10    3692.44
# Customer2     4215.67
# Customer3     1055.05
# Customer4     3337.37
# Customer5     1315.28
# Customer6     1930.76
# Customer7     2197.62
# Customer8     6498.91
# Customer9     1929.08
# Name: Profit, dtype: float64

# %%
ds['profit'] = (ds['selling price']- ds['buying price'])*ds['quantity sold']

# %%
ds
# Out:
#                   selling price  buying price  quantity bought  quantity sold  \
# Firm bought from
# Vendor1                  249.58        196.35              397            162
# Vendor10                 330.19        247.61              351            189
# Vendor2                  700.10        538.99              424            207
# Vendor3                  616.61        451.43              351            229
# Vendor4                  741.28        571.17              548            272
# Vendor5                  527.66        410.68              323             96
# Vendor6                  151.88        119.77              126             79
# Vendor7                 1054.14        829.16              629            270
# Vendor8                  201.80        166.14              133             23
# Vendor9                  600.69        435.43              279            170
#
#                     profit
# Firm bought from
# Vendor1            8623.26
# ...

# %%
ds['profit %']= (ds['profit']/(ds['buying price']*ds['quantity sold']))*100

# %%
ds
# Out:
#                   selling price  buying price  quantity bought  quantity sold  \
# Firm bought from
# Vendor1                  249.58        196.35              397            162
# Vendor10                 330.19        247.61              351            189
# Vendor2                  700.10        538.99              424            207
# Vendor3                  616.61        451.43              351            229
# Vendor4                  741.28        571.17              548            272
# Vendor5                  527.66        410.68              323             96
# Vendor6                  151.88        119.77              126             79
# Vendor7                 1054.14        829.16              629            270
# Vendor8                  201.80        166.14              133             23
# Vendor9                  600.69        435.43              279            170
#
#                     profit   profit %
# Firm bought from
# ...

# %%
ds['profit1'] = (ds['selling price']- ds['buying price'])*ds['quantity bought']

# %%
ds['profit1%']= (ds['profit1']/(ds['buying price']*ds['quantity bought']))*100
ds
# Out:
#                   selling price  buying price  quantity bought  quantity sold  \
# Firm bought from
# Vendor1                  249.58        196.35              397            162
# Vendor10                 330.19        247.61              351            189
# Vendor2                  700.10        538.99              424            207
# Vendor3                  616.61        451.43              351            229
# Vendor4                  741.28        571.17              548            272
# Vendor5                  527.66        410.68              323             96
# Vendor6                  151.88        119.77              126             79
# Vendor7                 1054.14        829.16              629            270
# Vendor8                  201.80        166.14              133             23
# Vendor9                  600.69        435.43              279            170
#
#                     profit   profit %    profit1   profit1%
# Firm bought from
# ...

# %%
ds['sold %'] = (ds['quantity sold']/ds['quantity bought'])*100

# %%
ds
# Out:
#                   selling price  buying price  quantity bought  quantity sold  \
# Firm bought from
# Vendor1                  249.58        196.35              397            162
# Vendor10                 330.19        247.61              351            189
# Vendor2                  700.10        538.99              424            207
# Vendor3                  616.61        451.43              351            229
# Vendor4                  741.28        571.17              548            272
# Vendor5                  527.66        410.68              323             96
# Vendor6                  151.88        119.77              126             79
# Vendor7                 1054.14        829.16              629            270
# Vendor8                  201.80        166.14              133             23
# Vendor9                  600.69        435.43              279            170
#
#                     profit   profit %    profit1   profit1%     sold %
# Firm bought from
# ...

# %%
ds.sort_values(by=['sold %','profit %'],ascending=False).head(1)
# Out:
#                   selling price  buying price  quantity bought  quantity sold  \
# Firm bought from
# Vendor3                  616.61        451.43              351            229
#
#                     profit   profit %   profit1   profit1%     sold %
# Firm bought from
# Vendor3           37826.22  36.590391  57978.18  36.590391  65.242165

# %%
x = "ponmurugan"
y=list(map(str,x))
y
# Out:
# ['p', 'o', 'n', 'm', 'u', 'r', 'u', 'g', 'a', 'n']

# %%
df.sort_values(by=['Buying price'],ascending=False).head(1)
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 34  2023-08-24          Vendor4         99.23               95  Customer1
#
#     Selling price  Quantity sold  Profit   Profit %     sold %
# 34         131.98             92  3013.0  33.004132  96.842105

# %%
df.sort_values(by=['Buying price'],ascending=True).head(1)
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 25  2023-08-23         Vendor10         10.19               42  Customer8
#
#     Selling price  Quantity sold  Profit   Profit %    sold %
# 25          11.65             25    36.5  14.327772  59.52381

# %%
df.sort_values(by=['Selling price'],ascending=False).head(1)
# Out:
#          Date Firm bought from  Buying price  Quantity bought   Customer  \
# 7  2023-08-21          Vendor3         98.11               62  Customer2
#
#    Selling price  Quantity sold  Profit   Profit %  sold %
# 7         146.76             62  3016.3  49.587198   100.0

# %%
df.sort_values(by=['Selling price'],ascending=True).head(1)
# Out:
#           Date Firm bought from  Buying price  Quantity bought   Customer  \
# 25  2023-08-23         Vendor10         10.19               42  Customer8
#
#     Selling price  Quantity sold  Profit   Profit %    sold %
# 25          11.65             25    36.5  14.327772  59.52381

# %%
#theoretically Vendor10 and Customer2 makes the maximum gross margin
